# %% [markdown]
# ### Business Problem
# Predicting Customer's average monthly spend from demographic features, Income Buying behaviour on a Bike ETC

# %% [markdown]
# This data is about a company's customers, including demographic features and information about purchases they have made. The company is particularly interested in analyzing customer data to determine any apparent relationships between demographic features known about the customers and the purchase behaviour.

# %%
#importing necessary reading, processing and visualization library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
#Importing all neccessary model for model evaluation 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from xgboost import XGBRegressor

# %% [markdown]
# ### Importing the Data

# %%
#Reading of all dataset
train = pd.read_csv('Competition 1- train_technidus.csv')
test = pd.read_csv('Competition 1- test_technidus.csv')
train['source'] = 'train'
test['source'] = 'test'
#concatinating train and test dataset
full_data = pd.concat([train, test], axis =0 )
print("shape of train data is: {}".format(train.shape))
print("shape of test data is: {}".format(test.shape))
print("shape of full_data data is: {}".format(full_data.shape))
full_data.head()
# Out:
# shape of train data is: (7654, 26)
# shape of test data is: (3340, 26)
# shape of full_data data is: (10994, 26)
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       22409   NaN    Candace        NaN    Madan    NaN
# 1       15809   NaN  Christian        NaN   Sharma    NaN
# 2       27510   NaN       Cole          Q   Bailey    NaN
# 3       17627   NaN     Dennis          M     Chen    NaN
# 4       21238   NaN       Carl        NaN     Tang    NaN
#
#            AddressLine1 AddressLine2            City StateProvinceName  ...  \
# 0        1488 Guadalupe          NaN      Hervey Bay        Queensland  ...
# 1  6086 Glen Wood Drive          NaN  Port Macquarie   New South Wales  ...
# 2     6253 Panorama Dr.          NaN      Burlingame        California  ...
# 3    3195 Rotherham Dr.          NaN      Maidenhead           England  ...
# 4    516 Oak Park Blvd.          NaN       Cliffside  British Columbia  ...
#
#   Gender MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# 0      F             S             1               0                    0
# 1      M             M             1               3                    4
# 2      M             S             0               2                    0
# 3      M             M             1               0                    1
# 4      M             S             0               2                    0
#
#   TotalChildren YearlyIncome AveMonthSpend  BikeBuyer  source
# 0             0        11336          37.0          0   train
# 1             5        81978         135.0          1   train
# 2             0        86892          70.0          0   train
# 3             1        68021          90.0          1   train
# 4             0        52525          64.0          1   train
#
# [5 rows x 26 columns]

# %%
#Data Type for each Attribute
types = full_data.dtypes
types
# Out:
# CustomerID                int64
# Title                    object
# FirstName                object
# MiddleName               object
# LastName                 object
# Suffix                   object
# AddressLine1             object
# AddressLine2             object
# City                     object
# StateProvinceName        object
# CountryRegionName        object
# PostalCode               object
# PhoneNumber              object
# BirthDate                object
# Education                object
# Occupation               object
# Gender                   object
# MaritalStatus            object
# HomeOwnerFlag             int64
# NumberCarsOwned           int64
# NumberChildrenAtHome      int64
# TotalChildren             int64
# YearlyIncome              int64
# AveMonthSpend           float64
# BikeBuyer                 int64
# source                   object
# dtype: object

# %%
#identifying all column in dataset 
full_data.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'AveMonthSpend', 'BikeBuyer', 'source'],
#       dtype='object')

# %% [markdown]
# ### Descriptive Statistics

# %%
#checking all Statistical attribute in datase for numerical variable
from pandas import set_option
set_option('display.width', 100)
set_option('precision', 3)
full_data.describe().T
# Out:
#                         count       mean        std      min       25%      50%        75%  \
# CustomerID            10994.0  20199.339   5340.164  11001.0  15586.50  20157.0   24832.75
# HomeOwnerFlag         10994.0      0.674      0.469      0.0      0.00      1.0       1.00
# NumberCarsOwned       10994.0      1.571      1.185      0.0      1.00      2.0       2.00
# NumberChildrenAtHome  10994.0      1.232      1.651      0.0      0.00      0.0       2.00
# TotalChildren         10994.0      2.149      1.723      0.0      1.00      2.0       4.00
# YearlyIncome          10994.0  82082.939  40696.256   9482.0  50395.25  81943.0  109796.75
# AveMonthSpend          7654.0     76.505     29.465     22.0     53.00     72.0      89.00
# BikeBuyer             10994.0      0.497      0.500      0.0      0.00      0.0       1.00
#
#                            max
# CustomerID             29481.0
# HomeOwnerFlag              1.0
# NumberCarsOwned            4.0
# NumberChildrenAtHome       5.0
# TotalChildren              5.0
# YearlyIncome          194314.0
# AveMonthSpend            176.0
# BikeBuyer                  1.0

# %%
#checking all Statistical attribute in datase for categorical variable
full_data.describe(include='object').T
# Out:
#                    count unique                  top  freq
# Title                 64      4                  Mr.    32
# FirstName          10994    633                Lucas    65
# MiddleName          6370     41                    L   766
# LastName           10994    319                 Diaz   133
# Suffix                 1      1                  Jr.     1
# AddressLine1       10994   8762    Attaché de Presse    11
# AddressLine2         183    111    Verkaufsabteilung    21
# City               10994    260               London   257
# StateProvinceName  10994     49           California  2614
# CountryRegionName  10994      6        United States  4581
# PostalCode         10994    312                91910   125
# PhoneNumber        10994   5383  1 (11) 500 555-0115   117
# BirthDate          10994   6349            6/24/1962     8
# Education          10994      5           Bachelors   3311
# Occupation         10994      5         Professional  3582
# Gender             10994      2                    M  5785
# MaritalStatus      10994      2                    M  5530
# source             10994      2                train  7654

# %% [markdown]
# ### Class Distribution (Classification Only)

# %%
class_counts = full_data.groupby('AveMonthSpend').size().plot(kind='hist')
print(class_counts)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# From the above, more of the data skewed to the Right between 1 - 25 spending habits

# %% [markdown]
# #### Corelations Between Attributes

# %%
correlations = full_data.corr(method='pearson')
print(correlations)
# Out:
#                       CustomerID  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# CustomerID                 1.000     -1.269e-01            0.002                -0.013
# HomeOwnerFlag             -0.127      1.000e+00           -0.031                 0.142
# NumberCarsOwned            0.002     -3.129e-02            1.000                 0.464
# NumberChildrenAtHome      -0.013      1.416e-01            0.464                 1.000
# TotalChildren             -0.011      1.987e-01            0.423                 0.707
# YearlyIncome              -0.046      4.540e-02            0.382                 0.380
# AveMonthSpend             -0.129      1.567e-01            0.395                 0.740
# BikeBuyer                 -0.003      6.665e-04            0.164                 0.445
#
#                       TotalChildren  YearlyIncome  AveMonthSpend  BikeBuyer
# CustomerID                   -0.011        -0.046         -0.129 -3.225e-03
# HomeOwnerFlag                 0.199         0.045          0.157  6.665e-04
# NumberCarsOwned               0.423         0.382          0.395  1.636e-01
# NumberChildrenAtHome          0.707         0.380          0.740  4.448e-01
# TotalChildren                 1.000         0.367          0.553  2.384e-01
# YearlyIncome                  0.367         1.000          0.619  2.973e-01
# AveMonthSpend                 0.553         0.619          1.000  4.192e-01
# BikeBuyer                     0.238         0.297          0.419  1.000e+00

# %% [markdown]
# ### Understanding Data with Visualization

# %% [markdown]
# ##### Univariate plots

# %%
#Univariate Histogram
full_data.hist(figsize=(8,8))
plt.show()

# %%
#Univeriate Density Plots
full_data.plot(kind='density', subplots=True, layout=(3,3), sharex=False, figsize=(9,9))
plt.show()

# %%
#Box ans Whisker Plots
full_data.plot(kind='box',subplots=True, layout=(3,3), sharex=False, figsize=(9,9))
plt.show()

# %% [markdown]
# #### Multivariate Plots

# %%
correlations = full_data.corr()
names = [ 
         
        'BirthDate',
       'HomeOwnerFlag',
       'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
       'YearlyIncome', 'AveMonthSpend', 'BikeBuyer']


fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
 
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels((names), rotation=45)
ax.set_yticklabels(names)
plt.show()

# %%
#scatterplot Matrix
from pandas.plotting import scatter_matrix
scatter_matrix(full_data,alpha=0.5, figsize=(20, 20))
plt.show()

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# #### Checking for missing Value

# %%
for i in full_data.columns:
    print(i + ": "+str(sum(full_data[i].isnull()))+" missing value")
# Out:
# CustomerID: 0 missing value
# Title: 10930 missing value
# FirstName: 0 missing value
# MiddleName: 4624 missing value
# LastName: 0 missing value
# Suffix: 10993 missing value
# AddressLine1: 0 missing value
# AddressLine2: 10811 missing value
# City: 0 missing value
# StateProvinceName: 0 missing value
# CountryRegionName: 0 missing value
# PostalCode: 0 missing value
# PhoneNumber: 0 missing value
# BirthDate: 0 missing value
# Education: 0 missing value
# Occupation: 0 missing value
# Gender: 0 missing value
# MaritalStatus: 0 missing value
# HomeOwnerFlag: 0 missing value
# NumberCarsOwned: 0 missing value
# NumberChildrenAtHome: 0 missing value
# TotalChildren: 0 missing value
# YearlyIncome: 0 missing value
# AveMonthSpend: 3340 missing value
# BikeBuyer: 0 missing value
# source: 0 missing value

# %% [markdown]
# #### Droping of uninformative columns
# This is as a result of the following
# 1. The column has only 30% of the data or less
# 2. irrelevant in prediting AveMonthSpend

# %%
#Print out all the columns that has less than 30% null values
nn_cols=[col for col in full_data.columns if train[col].count()<=0.7*len(train)]
print(nn_cols)
# Out:
# ['Title', 'MiddleName', 'Suffix', 'AddressLine2']

# %%
uninformative=['FirstName','LastName','CustomerID','PhoneNumber','PostalCode', 'Title', 
               'MiddleName', 'Suffix','AddressLine1', 'AddressLine2']
full_data.drop(uninformative,axis=1,inplace=True)
print("shape of full_data is: {}".format(full_data.shape))
# Out:
# shape of full_data is: (10994, 16)

# %% [markdown]
# ##### Treating AveMonthSpend missing value

# %%
#Treating AveMontSpend missing value 
gr = full_data.groupby(['Occupation', 'Education'])
gr.first()
# Out:
#                                                  City    StateProvinceName CountryRegionName  \
# Occupation     Education
# Clerical       Bachelors                   Hervey Bay           Queensland         Australia
#                Graduate Degree              Cambridge              England    United Kingdom
#                High School             Woodland Hills           California     United States
#                Partial College      Frankfurt am Main             Saarland           Germany
#                Partial High School        Chula Vista           California     United States
# Management     Bachelors                     Lakewood           California     United States
#                Graduate Degree              Daly City           California     United States
#                High School                  Paderborn  Nordrhein-Westfalen           Germany
#                Partial College                Seaford             Victoria         Australia
#                Partial High School             Melton             Victoria         Australia
# Manual         Bachelors                        Leeds              England    United Kingdom
#                Graduate Degree              Paderborn  Nordrhein-Westfalen           Germany
#                High School                   Woolston              England    United Kingdom
#                Partial College                   York              England    United Kingdom
#                Partial High School         Warrington              England    United Kingdom
# Professional   Bachelors                Coffs Harbour      New South Wales         Australia
#                Graduate Degree                Everett           Washington     United States
#                High School                    Bottrop  Nordrhein-Westfalen           Germany
#                Partial College             Burlingame           California     United States
#                Partial High School          Liverpool              England    United Kingdom
# Skilled Manual Bachelors                   Maidenhead              England    United Kingdom
#                Graduate Degree                  Colma           California     United States
#                High School                  Cliffside     British Columbia            Canada
#                Partial College         Port Macquarie      New South Wales         Australia
#                Partial High School        Saarbrücken             Saarland           Germany
#
#                                      BirthDate Gender MaritalStatus  HomeOwnerFlag  \
# Occupation     Education
# Clerical       Bachelors             8/15/1979      F             S              1
#                Graduate Degree       2/16/1961      F             M              1
#                High School           8/14/1955      M             S              1
#                Partial College        1/9/1979      M             S              1
#                Partial High School   7/18/1980      F             S              1
# Management     Bachelors             6/10/1962      M             S              0
#                Graduate Degree       8/27/1964      M             S              0
#                High School           11/7/1949      F             S              1
#                Partial College        5/1/1973      M             M              1
#                Partial High School  12/24/1971      F             M              1
# Manual         Bachelors             6/28/1958      M             M              1
#                Graduate Degree       1/11/1962      M             M              1
#                High School           8/26/1964      F             S              1
#                Partial College       8/25/1956      M             M              1
#                Partial High School  10/19/1964      F             S              1
# Professional   Bachelors              1/9/1971      M             S              1
#                Graduate Degree        7/1/1958      M             M              1
#                High School            2/8/1957      F             M              1
#                Partial College       10/3/1976      M             S              0
#                Partial High School    8/5/1947      M             M              1
# Skilled Manual Bachelors              9/9/1974      M             M              1
#                Graduate Degree       4/15/1958      F             M              1
#                High School           9/25/1980      M             S              0
#                Partial College       9/15/1960      M             M              1
#                Partial High School   7/19/1948      M             S              1
#
#                                     NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# Occupation     Education
# Clerical       Bachelors                          0                     0              0
#                Graduate Degree                    0                     0              4
#                High School                        2                     0              1
#                Partial College                    1                     3              3
#                Partial High School                2                     0              0
# Management     Bachelors                          4                     2              2
#                Graduate Degree                    2                     2              2
#                High School                        3                     5              5
#                Partial College                    3                     5              5
#                Partial High School                4                     5              5
# Manual         Bachelors                          0                     0              1
#                Graduate Degree                    0                     0              1
#                High School                        2                     2              2
#                Partial College                    0                     0              2
#                Partial High School                2                     3              4
# Professional   Bachelors                          3                     0              0
#                Graduate Degree                    0                     4              5
#                High School                        4                     4              4
#                Partial College                    2                     0              0
#                Partial High School                4                     5              5
# Skilled Manual Bachelors                          0                     1              1
#                Graduate Degree                    0                     0              5
#                High School                        2                     0              0
#                Partial College                    3                     4              5
#                Partial High School                4                     1              4
#
#                                     YearlyIncome  AveMonthSpend  BikeBuyer source
# Occupation     Education
# Clerical       Bachelors                   11336           37.0          0  train
#                Graduate Degree             66248           52.0          0  train
#                High School                 67848           68.0          0  train
#                Partial College             59227          100.0          1  train
#                Partial High School         48422           41.0          1  train
# Management     Bachelors                  162391          112.0          1  train
#                Graduate Degree            168757          115.0          1  train
#                High School                122319           95.0          1  train
#                Partial College            170456          168.0          1  train
#                Partial High School        144467          107.0          1  train
# Manual         Bachelors                   26678           66.0          0  train
#                Graduate Degree             44593           70.0          1  train
#                High School                 17476           55.0          1  train
#                Partial College             16593           66.0          0  train
#                Partial High School         13132           57.0          1  train
# Professional   Bachelors                  134331           81.0          1  train
#                Graduate Degree            137889          151.0          0  train
#                High School                138283           98.0          1  train
#                Partial College             86892           70.0          0  train
#                Partial High School        156236          165.0          1  train
# Skilled Manual Bachelors                   68021           90.0          1  train
#                Graduate Degree            114105           56.0          0  train
#                High School                 52525           64.0          1  train
#                Partial College             81978          135.0          1  train
#                Partial High School        108237           88.0          0  train

# %%
#checking for missing value in Avemonthspend
for i in full_data.columns:
    print(i + ": "+str(sum(full_data[i].isnull()))+" missing value")
# Out:
# City: 0 missing value
# StateProvinceName: 0 missing value
# CountryRegionName: 0 missing value
# BirthDate: 0 missing value
# Education: 0 missing value
# Occupation: 0 missing value
# Gender: 0 missing value
# MaritalStatus: 0 missing value
# HomeOwnerFlag: 0 missing value
# NumberCarsOwned: 0 missing value
# NumberChildrenAtHome: 0 missing value
# TotalChildren: 0 missing value
# YearlyIncome: 0 missing value
# AveMonthSpend: 3340 missing value
# BikeBuyer: 0 missing value
# source: 0 missing value

# %%
#converting YearlyIncome to MonthlyIncome since we are predicting AveMonthSpend
#full_data['MonthlyIncom'] = full_data['YearlyIncome']/12
# full_data.drop('YearlyIncome',axis=1,inplace=True)

# %% [markdown]
# #### Data preprocessing Continues

# %% [markdown]
# We will extract the years from *BirthDate* column and create a new column called *Year_of_Birth*. We will use this column to create bins used in our analysis.

# %%
#onvdrting BirthDate to year 
full_data['Year_of_Birth'] = pd.DatetimeIndex(full_data['BirthDate']).year
full_data.drop("BirthDate", axis=1, inplace=True)
full_data.head()
# Out:
#              City StateProvinceName CountryRegionName        Education      Occupation Gender  \
# 0      Hervey Bay        Queensland         Australia       Bachelors         Clerical      F
# 1  Port Macquarie   New South Wales         Australia  Partial College  Skilled Manual      M
# 2      Burlingame        California     United States  Partial College    Professional      M
# 3      Maidenhead           England    United Kingdom       Bachelors   Skilled Manual      M
# 4       Cliffside  British Columbia            Canada      High School  Skilled Manual      M
#
#   MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# 0             S              1                0                     0              0
# 1             M              1                3                     4              5
# 2             S              0                2                     0              0
# 3             M              1                0                     1              1
# 4             S              0                2                     0              0
#
#    YearlyIncome  AveMonthSpend  BikeBuyer source  Year_of_Birth
# 0         11336           37.0          0  train           1979
# 1         81978          135.0          1  train           1960
# 2         86892           70.0          0  train           1976
# 3         68021           90.0          1  train           1974
# 4         52525           64.0          1  train           1980

# %%
print("Year of birth of customers range from {} to {}".format(full_data["Year_of_Birth"].min(),
                                                              full_data["Year_of_Birth"].max()))
# Out:
# Year of birth of customers range from 1911 to 1980

# %%
#creating an array of bin used fo scaling 
bins = np.array([1911, 1960, 1980])
bins
# Out:
# array([1911, 1960, 1980])

# %%
group_names = ["Retired", "Not_Retired"]

# %%
#grouping the Year_of_birth into retired or not which range for 60 years and above Retired and others Not retird
full_data["Year_of_birth_binned"] = pd.cut(full_data["Year_of_Birth"], bins, labels=group_names, include_lowest=True)
full_data[["Year_of_Birth", "Year_of_birth_binned"]].head(20)
# Out:
#     Year_of_Birth Year_of_birth_binned
# 0            1979          Not_Retired
# 1            1960              Retired
# 2            1976          Not_Retired
# 3            1974          Not_Retired
# 4            1980          Not_Retired
# 5            1974          Not_Retired
# 6            1957              Retired
# 7            1979          Not_Retired
# 8            1960              Retired
# 9            1963          Not_Retired
# 10           1964          Not_Retired
# 11           1963          Not_Retired
# 12           1971          Not_Retired
# 13           1962          Not_Retired
# 14           1962          Not_Retired
# 15           1956              Retired
# 16           1964          Not_Retired
# 17           1954              Retired
# 18           1972          Not_Retired
# 19           1944              Retired

# %%
#visualising the Retired and Not retired in respect to AveMonthSpend
full_data.groupby(["Year_of_birth_binned"]).AveMonthSpend.sum().plot(kind="bar", color="darkblue")
plt.title("Customers Total Average Monthly Spend by Age bracket")
plt.ylabel("Customers Monthly spend")
plt.show()

# %% [markdown]
# ### $ Exploratory Data Analysis

# %%
full_data.hist(figsize=(8,8))
plt.show()

# %% [markdown]
# A few observations can be made based on the information and histograms for numerical features:
#
# 1. Year_of_birth is a slightly left-skewed normal distribution with the bulk of the staff born between 1960 and 1970.Data transformation methods may be required to approach a normal distribution prior to fitting a model to the data.
# 2. Target feature is also not normally distributed

# %%
#finding correlation between Numerical column
corrmat = full_data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True, annot=True);

# %% [markdown]
# **Assumption**
#
# 1. *TotalChildren* is highly correlated with *NumberChildrenAtHome* which is not good for our regression model
# 2. AveMonthSpend is positivly correlated with HomeOwnerFlag, NumberCarsOwned, NumberChildrenAtHome,TotalChildren, BikeBuyer and YearlyIncome
# 3. AveMonthSpend is negatively correlated with Year_of_Birth

# %%
#Observation of the distriution of AveMonthSpend
sns.distplot(full_data[full_data['source'] == 'train'].AveMonthSpend)

# %%
#plot to count gender 
sns.countplot(x='Gender',data=full_data)

# %%
#observation of MonthlySpending  and Yearly income for male and female
var = 'YearlyIncome'
data = pd.concat([full_data['AveMonthSpend'], full_data[var]], axis=1)
sns.lmplot(x=var,y='AveMonthSpend',data=full_data,hue='Gender')

# %% [markdown]
# It appears the Male's earns more than the female counterpart. Just like the law of abnormal demand thats states, the higher the price the higher the quantity demanded. Thus the higher the income the higher the Monthly spending. There was also a very high concerntration between 80 - 60.

# %%
#plot to show the various Occupation, their Income and spending count
sns.lmplot(x='YearlyIncome',y='AveMonthSpend',data=full_data,col='Occupation')

# %% [markdown]
# The Target Occupation here are Professional's and Management which had a high income and spend the most among others

# %%
#plot to show the Ave monthly spending for genders as to total number of childern 
sns.lmplot(x="YearlyIncome", y="AveMonthSpend", row="Gender", col="TotalChildren",data=full_data)

# %%
#plot to show the various customer Educational qualification, their Income and spending count
sns.lmplot(x='YearlyIncome',y='AveMonthSpend',data=full_data,col='Education')

# %%
#plot showing maritalStatus and thir number of children at home aainst their spending monthly 
sns.lmplot(x="YearlyIncome", y="AveMonthSpend", row="MaritalStatus", col="NumberChildrenAtHome",data=full_data)

# %%
#plot showing countries from customers and their monthly and monthly spending
sns.lmplot(x='YearlyIncome',y='AveMonthSpend',data=full_data,col='CountryRegionName')

# %% [markdown]
# It is interesting to know customers from UK have more high income earners but customers from Australia spends more

# %%
#plot showing customer based on country and their gender against their spending monthly 
sns.stripplot(x="CountryRegionName", y="AveMonthSpend", data=full_data,hue='Gender',palette='Set1')

# %% [markdown]
# ## Model

# %%
full_data.head()
# Out:
#              City StateProvinceName CountryRegionName        Education      Occupation Gender  \
# 0      Hervey Bay        Queensland         Australia       Bachelors         Clerical      F
# 1  Port Macquarie   New South Wales         Australia  Partial College  Skilled Manual      M
# 2      Burlingame        California     United States  Partial College    Professional      M
# 3      Maidenhead           England    United Kingdom       Bachelors   Skilled Manual      M
# 4       Cliffside  British Columbia            Canada      High School  Skilled Manual      M
#
#   MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# 0             S              1                0                     0              0
# 1             M              1                3                     4              5
# 2             S              0                2                     0              0
# 3             M              1                0                     1              1
# 4             S              0                2                     0              0
#
#    YearlyIncome  AveMonthSpend  BikeBuyer source  Year_of_Birth Year_of_birth_binned
# 0         11336           37.0          0  train           1979          Not_Retired
# 1         81978          135.0          1  train           1960              Retired
# 2         86892           70.0          0  train           1976          Not_Retired
# 3         68021           90.0          1  train           1974          Not_Retired
# 4         52525           64.0          1  train           1980          Not_Retired

# %%
#droping correlated column and some irrelevant column
full_data.drop(['City','TotalChildren','StateProvinceName'], axis=1, inplace=True)

# %%
new_train = full_data[full_data.source == 'train']
new_test = full_data[full_data.source== 'test']
print("shape of new_train data is: {}".format(new_train.shape))
print("shape of new_test data is: {}".format(new_test.shape))
# Out:
# shape of new_train data is: (7654, 14)
# shape of new_test data is: (3340, 14)

# %%
new_train = new_train.copy()
new_test = new_train.copy()

# %%
new_train.drop(['source'],axis=1, inplace=True)
new_test.drop(['source'],axis=1,inplace=True)

# %%
new_test.shape, new_train.shape
# Out:
# ((7654, 13), (7654, 13))

# %% [markdown]
# #### Cloumn Transformation

# %%
# determine categorical and numerical features
numerical_ix = new_train.select_dtypes(include=['int64', 'float64']).columns
categorical_ix = new_train.select_dtypes(include=['object', 'bool']).columns

# %%
numerical_ix,categorical_ix
# Out:
# (Index(['HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome', 'YearlyIncome', 'AveMonthSpend',
#         'BikeBuyer', 'Year_of_Birth'],
#        dtype='object'),
#  Index(['CountryRegionName', 'Education', 'Occupation', 'Gender', 'MaritalStatus'], dtype='object'))

# %%
import category_encoders as ce

#Label encoding
cat_cols = ['Gender', 'MaritalStatus', 'CountryRegionName', 'Education', 'Occupation','Year_of_birth_binned'] 

encoder = ce.OrdinalEncoder(cols=cat_cols)
new_train = encoder.fit_transform(new_train)

# %%
correlations = new_train.corr()['AveMonthSpend'].sort_values()
print('Most Positive Correlations: \n', correlations.tail(10))
print('\nMost Negative Correlations: \n', correlations.head(3))
# Out:
# Most Positive Correlations:
#  Year_of_birth_binned    0.029
# HomeOwnerFlag           0.157
# Occupation              0.197
# MaritalStatus           0.259
# NumberCarsOwned         0.395
# BikeBuyer               0.419
# Gender                  0.559
# YearlyIncome            0.619
# NumberChildrenAtHome    0.740
# AveMonthSpend           1.000
# Name: AveMonthSpend, dtype: float64
#
# Most Negative Correlations:
#  CountryRegionName   -0.108
# Education           -0.097
# Year_of_Birth       -0.029
# Name: AveMonthSpend, dtype: float64

# %%
drop = ['Year_of_birth_binned','AveMonthSpend' ]
X = new_train.drop(drop, axis= 1)
y = new_train["AveMonthSpend"]

# %%
X.shape,y.shape
# Out:
# ((7654, 11), (7654,))

# %%
X.values
# Out:
# array([[     1,      1,      1, ...,  11336,      0,   1979],
#        [     1,      2,      2, ...,  81978,      1,   1960],
#        [     2,      2,      3, ...,  86892,      0,   1976],
#        ...,
#        [     1,      5,      5, ..., 136290,      0,   1969],
#        [     2,      2,      2, ...,  91408,      0,   1960],
#        [     2,      2,      3, ...,  93561,      0,   1951]], dtype=int64)

# %%
#X.to_csv('aveincome.csv')

# %% [markdown]
# ## Model Evaluation and Optimization

# %%
#Baseline model
from numpy import mean
from numpy import std
from numpy import absolute
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.dummy import DummyRegressor
#checking baseline model with an algorithm 
x_ = X
y_ = y
naive = DummyRegressor(strategy='median')
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(naive, x_, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
n_scores = absolute(n_scores)
print('Baseline: %.3f (%.3f)' % (np.sqrt(n_scores.mean()), std(n_scores.mean())))
# evaluate model
model = XGBRegressor(objective='reg:squarederror')
m_scores = cross_val_score(model, x_, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
m_scores = absolute(m_scores)
print('Good: %.3f (%.3f)' % (np.sqrt(m_scores.mean()), std(m_scores.mean())))
# Out:
# Baseline: 4.705 (0.000)
# Good: 1.601 (0.000)

# %%
#importing Scalers to test 
from sklearn.preprocessing import StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
ss = StandardScaler()
rs = RobustScaler()
qt = QuantileTransformer(output_distribution='normal',n_quantiles=3864)
yj = PowerTransformer(method = 'yeo-johnson')
bc = PowerTransformer(method = 'box-cox')

# %%
ss_data = pd.DataFrame(ss.fit_transform(x_), columns = x_.columns)
rs_data = pd.DataFrame(rs.fit_transform(x_), columns = x_.columns)
qt_data = pd.DataFrame(qt.fit_transform(x_), columns = x_.columns)
yj_data = pd.DataFrame(yj.fit_transform(x_), columns = x_.columns)
# Out:
# C:\Users\Richie\miniconda3\envs\tensorflow\lib\site-packages\sklearn\preprocessing\_data.py:2947: RuntimeWarning: overflow encountered in power
#   out[pos] = (np.power(x[pos] + 1, lmbda) - 1) / lmbda
# C:\Users\Richie\miniconda3\envs\tensorflow\lib\site-packages\numpy\core\_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\Richie\miniconda3\envs\tensorflow\lib\site-packages\numpy\core\_methods.py:199: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %%
#compering scalars with baseline line model and Xgboost 
naive = DummyRegressor(strategy='median')
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(naive, ss_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
n_scores = absolute(n_scores)
print('Baseline for ss: %.3f (%.3f)' % (np.sqrt(n_scores.mean()), std(n_scores.mean())))
# evaluate model
model = XGBRegressor(objective='reg:squarederror')
m_scores = cross_val_score(model, ss_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
m_scores = absolute(m_scores)
print('Good: %.3f (%.3f)' % (np.sqrt(m_scores.mean()), std(m_scores.mean())))

naive = DummyRegressor(strategy='median')
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(naive, rs_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
n_scores = absolute(n_scores)
print('Baseline for rs: %.3f (%.3f)' % (np.sqrt(n_scores.mean()), std(n_scores.mean())))
# evaluate model
model = XGBRegressor(objective='reg:squarederror')
m_scores = cross_val_score(model, rs_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
m_scores = absolute(m_scores)
print('Good: %.3f (%.3f)' % (np.sqrt(m_scores.mean()), std(m_scores.mean())))

naive = DummyRegressor(strategy='median')
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(naive, qt_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
n_scores = absolute(n_scores)
print('Baseline for qt: %.3f (%.3f)' % (np.sqrt(n_scores.mean()), std(n_scores.mean())))
# evaluate model
model = XGBRegressor(objective='reg:squarederror')
m_scores = cross_val_score(model, qt_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
m_scores = absolute(m_scores)
print('Good: %.3f (%.3f)' % (np.sqrt(m_scores.mean()), std(m_scores.mean())))

naive = DummyRegressor(strategy='median')
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(naive, yj_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
n_scores = absolute(n_scores)
print('Baseline for yj: %.3f (%.3f)' % (np.sqrt(n_scores.mean()), std(n_scores.mean())))
# evaluate model
model = XGBRegressor(objective='reg:squarederror')
m_scores = cross_val_score(model, yj_data, y_, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
m_scores = absolute(m_scores)
print('Good: %.3f (%.3f)' % (np.sqrt(m_scores.mean()), std(m_scores.mean())))
# Out:
# Baseline for ss: 4.705 (0.000)
# Good: 1.601 (0.000)
# Baseline for rs: 4.705 (0.000)
# Good: 1.601 (0.000)
# Baseline for qt: 4.705 (0.000)
# Good: 1.601 (0.000)
# Baseline for yj: 4.705 (0.000)
# Good: 1.601 (0.000)

# %%
#Splitting dataset 
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = train_test_split(X.as_matrix(), y.as_matrix(),
test_size=validation_size,shuffle=True, random_state=seed)

print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", Y_train.shape)
print("Number transactions X_validation dataset: ", X_validation.shape)
print("Number transactions y_validation dataset: ", Y_validation.shape)
# Out:
# Number transactions X_train dataset:  (6123, 11)
# Number transactions y_train dataset:  (6123,)
# Number transactions X_validation dataset:  (1531, 11)
# Number transactions y_validation dataset:  (1531,)
# C:\Users\Richie\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
#creating a function to calculate RMSE
def evaluate_rmse(y, pred):
    results = mean_squared_error(y, pred)
    return np.sqrt(results)
num_folds = 10
scoring = 'neg_mean_squared_error'

models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('SVR', SVR()))
models.append(('XGB', XGBRegressor(objective= 'reg:squarederror')))
models.append(('RGF', RandomForestRegressor()))
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=num_folds, shuffle=True, random_state=1)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, np.sqrt(np.abs(cv_results.mean())), np.sqrt(cv_results.std()))
    print(msg)
# Out:
# LR: 6.733091 (1.950888)
# LASSO: 7.398283 (2.051365)
# EN: 12.924311 (2.947538)
# KNN: 24.583765 (5.837231)
# CART: 4.495316 (0.953371)
# SVR: 22.963056 (6.585543)
# XGB: 3.233901 (0.652470)
# RGF: 3.475887 (0.503696)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Scaled Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# XGBoost and RandomForest did the best with a good STD

# %%
# prepare the model
#using RandomForest
model_base0 =  RandomForestRegressor()
model_base0.fit(X_train, Y_train)
pred_train = model_base0.predict(X_train)
pred_test = model_base0.predict(X_validation)
print('Train RMSE: ', evaluate_rmse(Y_train, pred_train))
#print('Test_clean RMSE: ' ,evaluate_rmse(test.price, pred_test))
print('Test RMSE: ' ,evaluate_rmse(Y_validation, pred_test))
# Out:
# Train RMSE:  1.29479896532533
# Test RMSE:  3.424614544907027

# %%
import category_encoders as ce

#Label encoding
cat_cols = ['Gender', 'MaritalStatus', 'CountryRegionName', 'Education', 'Occupation','Year_of_birth_binned'] 

encoder = ce.OrdinalEncoder(cols=cat_cols)
new_test = encoder.fit_transform(new_test)

# %%
newtest = new_test.drop(drop, axis=1)

# %%
#predicting actual test dataset
test_predictions = model_base0.predict(newtest)
test_predictions[:5]
# Out:
# array([ 38.86, 135.02,  70.31,  89.32,  61.88])

# %%
#plotting our prediction and  test prediction 
sns.distplot(test_predictions, hist=False, rug=True)
sns.distplot(pred_train, hist=False, rug=True)

# %%
# Saving model to disk
import pickle
pickle.dump(model_base0, open('model1.pkl','wb'))

# Loading model to compare the results
model = pickle.load(open('model1.pkl','rb'))
print(model.predict(newtest))
